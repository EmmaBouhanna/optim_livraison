# %%
from visualisation import *

# %%
df_complete = pd.read_csv('./output_data_bis/df_complete.csv', usecols = ["y", "x", "name", "type", "adress"])
df_complete
# Out:
#             y         x                        name               type  \
# 0   48.754897  2.366262    Agence Chronopost Rungis  Agence Chronopost
# 1   48.714794  2.302966     Agence Chronopost Massy  Agence Chronopost
# 2   48.967846  2.490294    Agence Chronopost Aulnay  Agence Chronopost
# 3   48.911495  2.433059   Agence Chronopost Bobigny  Agence Chronopost
# 4   48.842213  2.301509  Agence Chronopost Lecourbe  Agence Chronopost
# ..        ...       ...                         ...                ...
# 65  48.630049  2.058331                   Client 45                NaN
# 66  48.543402  3.293122                   Client 46                NaN
# 67  49.058208  2.494200                   Client 47                NaN
# 68  48.921308  1.872210                   Client 48                NaN
# 69  48.591244  2.222510                   Client 49                NaN
#
#                                                adress
# 0   Centre technique routier D, 3 Rue des Transpor...
# ...

# %%
visualize_nearest_nodes(df_complete, n_warehouses=20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
visualize_travel_between_two_nodes(69, 31, line_color='cyan')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
start_time = time.time()

map_test = visualize_single_truck_travel([16, 56, 49, 16], color='purple')

print(f"temps d'exécution : {start_time - time.time()} secondes")

map_test
# Out:
# temps d'exécution : -42.8624222278595 secondes
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
visualize_single_warehouse_travel('./output_data/res_entrepot_13.csv')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
